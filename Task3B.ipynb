# %% [markdown]
# <a href="https://colab.research.google.com/github/RumeysaBalabey/VeriBilimi/blob/main/Task3B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data_all = pd.read_csv("MRI_and_CDRinfo_Values_X_train.csv")
data_all
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (22,24,41,46,48,51,90,91,92,93,94,95,96,97,98,99,100,167,205,208,210,213,216,219,221,223,225,227,229,231,235,237,239,241,243,245,247,249,251,253,255,365,380,382,384,402,404,406,551,634,651,654,659,689,770,776,900,908,943,946,964,965,974,1176) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#       Unnamed: 0  Unnamed: 0.1  index_x    NACCID_x  NACCADC_x PACKET  \
# 0           1970          1970   116428  NACC831508       6518      I
# 1           1146          1146   110463  NACC719761       6499      I
# 2            675           675   106548  NACC979197       6061      F
# 3           1268          1268   111371  NACC917131       6499      I
# 4           2323          2323   161286  NACC056098       9661      F
# ...          ...           ...      ...         ...        ...    ...
# ...

# %%
data_labels = pd.read_csv("CDR_Values_y_train.csv")
data_labels
# Out:
#       Unnamed: 0  CDRGLOB
# 0           1970        0
# 1           1146        0
# 2            675        0
# 3           1268        2
# 4           2323        0
# ...          ...      ...
# 1583         984        1
# 1584        1325        1
# 1585         788        2
# 1586         195        1
# 1587        1206        0
#
# [1588 rows x 2 columns]

# %%
data_all['HIPPOVOL'].describe()
# Out:
# count    1588.000000
# mean        5.951227
# std         0.925175
# min         2.971900
# 25%         5.346000
# 50%         5.980000
# 75%         6.600250
# max         9.696500
# Name: HIPPOVOL, dtype: float64

# %%
#dağılımı görmek ve yorulmayabilmek adına histogram çizdirelim
import matplotlib.pyplot as plt
data_hip = data_all["HIPPOVOL"].hist(bins = 100)
#dağılımın normla dağılım olduğunu ve ortalamasının 5.95 standart sapmasının ise 0.92 olduğunu söyleyebiliriz.

# %%
data_labels['HIP_VOL'] = data_all['HIPPOVOL']

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].count()
# Out:
#          HIP_VOL
# CDRGLOB
# 0            721
# 1            607
# 2            194
# 3             66

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].mean()
# Out:
#           HIP_VOL
# CDRGLOB
# 0        6.304869
# 1        5.839063
# 2        5.323365
# 3        4.965071

# %%
data_labels.groupby('CDRGLOB')[['HIP_VOL']].std()
# Out:
#           HIP_VOL
# CDRGLOB
# 0        0.757105
# 1        0.866157
# 2        0.974990
# 3        1.031115

# %%
#son olarak describe fonksiyonuyla elded ettiğimiz sonuçları karakteristik özellikleri bir araya getiriyoruz
data_labels.groupby('CDRGLOB')[['HIP_VOL']].describe()
# Out:
#         HIP_VOL                                                          \
#           count      mean       std     min       25%      50%      75%
# CDRGLOB
# 0         721.0  6.304869  0.757105  4.1340  5.781000  6.25570  6.84860
# 1         607.0  5.839063  0.866157  3.0209  5.264750  5.81930  6.40115
# 2         194.0  5.323365  0.974990  2.9719  4.579325  5.35495  5.97160
# 3          66.0  4.965071  1.031115  3.1056  4.347850  4.84365  5.43490
#
#
#             max
# CDRGLOB
# 0        9.6965
# 1        8.9606
# 2        7.9945
# 3        7.7950

# %% [markdown]
# HIP_VOL ortalaması ve standart sapmasının AD değeriyle ters orantılı olduğunu gözlemlemiş olduk.
